# %% [markdown]
# <a href="https://colab.research.google.com/github/robbi621/sentiment-twitter/blob/main/Codingan_Rumor_Twitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy
import re
from textblob import TextBlob

# %%
api_key = "0Zccf5G0PJ5Hv7H4WeD9AG6xP"
api_secret_key = "wA5zzgWMZIUzj7qbg4UYNeqjL6YiuzKjemjNle80k300iLh9y9"
access_token = "1104250246136131584-r7DJgVOLbaP9eSTi2VrvWR31aJovz0"
access_token_secret = "lSGT7xnNCn2khMog748PzVWtHj9hVlGi2rraR8PEN9LVZ"

# %%
auth = tweepy.OAuthHandler(api_key, api_secret_key)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
hasilSearch = api.search (q="elon musk", lang="id", count=100)

# %%
hasilAnalisis = []

for tweet in hasilSearch:
  tweet_properties = {}
  tweet_properties["tanggal_tweet"] = tweet.created_at
  tweet_properties["pengguna"] = tweet.user.screen_name
  tweet_properties["isi_tweet"] = tweet.text
  tweet_bersih = ''.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\s+)"," ",tweet.text).split())
  
  analysis = TextBlob(tweet_bersih)
  try:
    analysis = analysis.translate(to="en")
  except Exception as e:
    print(e)
  
  if analysis.sentiment.polarity > 0.0:
    tweet_properties["sentiment"] = "positif"
  elif analysis.sentiment.polarity == 0.0:
    tweet_properties["sentiment"] = "netral"
  else:
    tweet_properties["sentiment"] = "negatif"

  if tweet.retweet_count > 0:
    if tweet_properties not in hasilAnalisis:
      hasilAnalisis.append(tweet_properties)
  else:
    hasilAnalisis.append(tweet_properties)
# Out:
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.

# %%
tweet_positif = [t for t in hasilAnalisis if t ["sentiment"]=="positif"]
tweet_netral = [t for t in hasilAnalisis if t ["sentiment"]=="netral"]
tweet_negatif = [t for t in hasilAnalisis if t ["sentiment"]=="negatif"]

# %%
print("hasil sentiment")
print("positif: ", len(tweet_positif), "({} %)".format(100*len(tweet_positif)/len(hasilAnalisis)))
print("netral: ", len(tweet_netral), "({} %)".format(100*len(tweet_netral)/len(hasilAnalisis)))
print("negatif: ", len(tweet_negatif), "({} %)".format(100*len(tweet_negatif)/len(hasilAnalisis)))
# Out:
# hasil sentiment
# positif:  4 (4.0 %)
# netral:  69 (69.0 %)
# negatif:  27 (27.0 %)

# %%
tweet_positif
# Out:
# [{'isi_tweet': '"Di tengah pergerakan dan kekacauan, jagalah ketenangan di dalam dirimu." ~Deepak Chopra\n\nSelamatt berakhir pekan j… https://t.co/IIt7YXb26v',
#   'pengguna': 'MoelyonovDjalil',
#   'sentiment': 'positif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 31, 5)},
#  {'isi_tweet': '@crisdiantoro Menarik memang, sayangnya yang tau ini yg udah terjun lama dan saat ini market crypto lagi in banget… https://t.co/AWaLd2yIkw',
#   'pengguna': 'coinvestasi',
#   'sentiment': 'positif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 25, 47)},
#  {'isi_tweet': 'Dalam crypto ni ada candle baru tuan2. Dia panggil Elon Musk candle. Dia tweet ja habis merah',
#   'pengguna': 'ikhwankweng',
#   'sentiment': 'positif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 24, 5)},
#  {'isi_tweet': 'Elon musk power off bitcoin\nSiapakah sia sebenarnya sampai bisa menggoyangkan pikiran umat manusia didunia https://t.co/vyYaZ2qhES',
#   'pengguna': 'RezqiWismaPutra',
#   'sentiment': 'positif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 48, 4)}]

# %%
tweet_netral
# Out:
# [{'isi_tweet': 'temen gw main crypto invest cuman 100 ribu, ocehannya dah kayak elon musk',
#   'pengguna': 'kaptenkreco',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 35, 28)},
#  {'isi_tweet': 'Elon musk asu, gabole bgt aing dapet profit ngentot 🔫',
#   'pengguna': 'adamanugrahpn',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 34, 59)},
#  {'isi_tweet': 'RT @mbah_mijan: Elon Musk belum tau santet!\n\nOrang ini lidah bercabang, setelah mengumumkan Tesla bisa ditukar Bitcoin, dia sendiri yang me…',
#   'pengguna': 'adieepk',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 33, 48)},
#  {'isi_tweet': '@cz_binance Elon musk Madafaka https://t.co/DrTWFHAHzn',
#   'pengguna': 'DodiWij66182042',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 33, 21)},
#  {'isi_tweet': 'Nyindir Elon musk nih https://t.co/qADPEig1p5',
#   'pengguna': 'Dikibuliinn',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 32, 50)},
#  {'isi_tweet': 'RT @michaelbataraa: Gara-gara Elon Musk, tetangga gue yg tadinya main Crypto, sekarang main Kredivo wkwk.',
#   'pengguna': 'ridhoni',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 32, 7)},
#  {'isi_tweet': 'Bun inilah potret trading ikut ikutan influencer gajelas. udah di peringatin padahal ngeyel. apalagi murid… https://t.co/MeC8K5Rub5',
#   'pengguna': 'urdeepsadness',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 31, 46)},
#  {'isi_tweet': 'pgn kyk elon musk, tiap ngetweet yang keguncang satu dunia',
#   'pengguna': 'RazifIqbal02',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 28, 52)},
#  {'isi_tweet': 'RT @michaelbataraa: Gara-gara Elon Musk, tetangga gue yg tadinya main Crypto, sekarang main Kredivo wkwk.',
#   'pengguna': 'Anassss_17',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 27, 54)},
#  {'isi_tweet': 'RT @3bearinthedark: Semua masuk surga kecuali elon musk',
#   'pengguna': 'Dhamas_S',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 27, 35)},
#  {'isi_tweet': 'Raffi ahmad,, Elon Musk nya Indonesia...🤭🤭🤭\n\n#TEN #Elonmusk #cryptocurrency #Tokenomimarket',
#   'pengguna': 'nengandinmanise',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 27, 13)},
#  {'isi_tweet': 'Punyalah sturggle tengok graf, ikut analisis orang sekali tweet elon musk jugak bagi effect',
#   'pengguna': 'haaziqnazmi',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 25, 37)},
#  {'isi_tweet': 'RT @CNNIndonesia: Emoji Patah Hati Elon Musk Buat Harga Bitcoin Turun 4 Persen https://t.co/pHamjErjt6',
#   'pengguna': 'akmalarif90',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 23, 46)},
#  {'isi_tweet': 'Kenapa elon musk ga di unfollow aja? #unfollowelonmusk #BTC #Binance',
#   'pengguna': '_riv13',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 22, 27)},
#  {'isi_tweet': 'RT @CNNIndonesia: Emoji Patah Hati Elon Musk Buat Harga Bitcoin Turun 4 Persen https://t.co/pHamjErjt6',
#   'pengguna': 'Yusuf71366542',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 21, 43)},
#  {'isi_tweet': 'Emoji Patah Hati Elon Musk Buat Harga Bitcoin Turun 4 Persen https://t.co/pHamjErjt6',
#   'pengguna': 'CNNIndonesia',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 19, 48)},
#  {'isi_tweet': 'sumpah pgn mukul dadanya elon musk',
#   'pengguna': 'farhanstaaa',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 18, 58)},
#  {'isi_tweet': 'RT @michaelbataraa: Gara-gara Elon Musk, tetangga gue yg tadinya main Crypto, sekarang main Kredivo wkwk.',
#   'pengguna': 'syamsulgomu',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 14, 46)},
#  {'isi_tweet': '@gauravdahake @elonmusk Ji han Gaurav ji,\nVaise b Elon Musk k tweet ka itna impact ab nhi hota crypto market pr..',
#   'pengguna': 'SureshP81151123',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 10, 53)},
#  {'isi_tweet': 'Ayo gaes, siapa yang cita-citanya ingin gebukin Elon Musk di Padang Mahsyar? https://t.co/uNjdBTcbrs',
#   'pengguna': 'pramerdeka',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 9, 20)},
#  {'isi_tweet': '@uinibihukijeM Julungi beliau peluit sama meolah beliau sugih kaya elon musk',
#   'pengguna': 'GustiFullah',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 5, 55)},
#  {'isi_tweet': '@cz_binance Ogun go kee Elon musk papa.',
#   'pengguna': 'c3coolasice',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 3, 25)},
#  {'isi_tweet': 'Hayo siapa yg kegocek elon musk lagi ? 😂',
#   'pengguna': 'aksansudari',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 2, 55)},
#  {'isi_tweet': '@oscarvalentino7 Tp aku setuju sih dgn pernyataan, klw elon musk itu lidah ny bercabang...',
#   'pengguna': 'MFArsyad',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 1, 35)},
#  {'isi_tweet': 'Elon musk ngetweet lagi kan 😆 https://t.co/8dY4wxTM1W',
#   'pengguna': 'nggaktaula',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 57, 27)},
#  {'isi_tweet': '@mbah_mijan mbah elon musk mau mbah santet?',
#   'pengguna': 'phroggingphrog',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 42, 49)},
#  {'isi_tweet': 'ELON MUSK NGENTOT CUMA BISA NGEFUD DOANG',
#   'pengguna': 'ZakariaPriyadi',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 42, 14)},
#  {'isi_tweet': 'ngehold koin dibawah naungan elon musk udah kaya toxic relationship',
#   'pengguna': 'gochabebe',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 41, 44)},
#  {'isi_tweet': 'Sabar om cz, Elon musk emang kerjaannya gitu,dibayar buat ngedump #Bitcoin, kalo ga gitu mana bisa bikin Tesla 🤣🤣 https://t.co/StBWyMPEP4',
#   'pengguna': 'Richardo_PN',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 41, 10)},
#  {'isi_tweet': 'Elon Musk ni apesal perangai rempit sangat.',
#   'pengguna': 'adiariff_mohd',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 40, 28)},
#  {'isi_tweet': 'RT @mbah_mijan: Jika kamu rugi besar di crypto gara-gara cuitan seorang Elon Musk, jangan pernah mimpi "To The Moon" lagi.\n\nSaatnya kalian…',
#   'pengguna': 'tony888800',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 29, 14)},
#  {'isi_tweet': '@wsupbabe pasti km keponakan elon musk',
#   'pengguna': 'agalisme',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 24, 40)},
#  {'isi_tweet': 'Ya tapi siapa tau elon musk lagi ga becanda tapi ada maksud lain',
#   'pengguna': 'JohnMeyerds',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 24, 1)},
#  {'isi_tweet': 'RT @Cryptofess_: CZ dan Justin Sun dah mulai gerah, yuk gas buat mengenang akun Elon Musk, Trump aja bisa dibanned, masak EM gak bisa diban…',
#   'pengguna': 'dapinin',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 22, 31)},
#  {'isi_tweet': 'RT @Cryptofess_: CZ dan Justin Sun dah mulai gerah, yuk gas buat mengenang akun Elon Musk, Trump aja bisa dibanned, masak EM gak bisa diban…',
#   'pengguna': 'gicill',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 20, 33)},
#  {'isi_tweet': 'Bukan Elon Musk, Dua Anak Muda Ini Jadi Miliarder dan Pemegang Kripto Terbesar di Dunia! https://t.co/S55JECEfOs',
#   'pengguna': 'Bisniscom',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 18, 7)},
#  {'isi_tweet': 'RT @michaelbataraa: Gara-gara Elon Musk, tetangga gue yg tadinya main Crypto, sekarang main Kredivo wkwk.',
#   'pengguna': 'bintangbayukp',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 16, 57)},
#  {'isi_tweet': 'emang anjing nih si elon musk https://t.co/SEwr0zD1H5',
#   'pengguna': 'chanskillyou',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 16, 47)},
#  {'isi_tweet': 'RT @michaelbataraa: Gara-gara Elon Musk, tetangga gue yg tadinya main Crypto, sekarang main Kredivo wkwk.',
#   'pengguna': 'protipsure',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 14, 1)},
#  {'isi_tweet': 'Elon Musk lagi-lagi bikin sensasi. Tweet terbaru Musk, pada Jumat (4/6), ada simbol patah hati. Harga Bitcoin jatuh… https://t.co/WgMmZEa4Ba',
#   'pengguna': 'HariankriptoId',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 14)},
#  {'isi_tweet': 'RT @Cryptofess_: CZ dan Justin Sun dah mulai gerah, yuk gas buat mengenang akun Elon Musk, Trump aja bisa dibanned, masak EM gak bisa diban…',
#   'pengguna': 'NikkoRianto',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 13, 39)},
#  {'isi_tweet': 'CZ dan Justin Sun dah mulai gerah, yuk gas buat mengenang akun Elon Musk, Trump aja bisa dibanned, masak EM gak bis… https://t.co/je2Zi6ZfYi',
#   'pengguna': 'Cryptofess_',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 11, 51)},
#  {'isi_tweet': '@Pirjinya Itu anaknya elon musk ?',
#   'pengguna': 'DIDIKBIMA',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 11, 45)},
#  {'isi_tweet': 'RT @IntradayDotMy: Pelabur kripto lepas Elon Musk tweet pasal #bitcoin https://t.co/IgBg79PICU',
#   'pengguna': 'zaidinabass1',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 10, 16)},
#  {'isi_tweet': 'Masih anget, ini artikel yang jelasin kenapa Elon Musk gak cocok jadi panutan buat para investor crypto. Bukan fina… https://t.co/jp2evh1H6g',
#   'pengguna': 'coinvestasi',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 9, 40)},
#  {'isi_tweet': 'elon musk: "lha gue kan pengen becanda doaaaang"',
#   'pengguna': 'ramaSM_',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 5, 18)},
#  {'isi_tweet': '@EbonyAShakur $CUM BSC #elon $musk contract: 0xc0d25180fd2e1549275ba13ea0ae5921da08d64b',
#   'pengguna': 'ProjectKinu',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 4, 15)},
#  {'isi_tweet': '@IK_UK_ $CUM BSC #elon $musk contract: 0xc0d25180fd2e1549275ba13ea0ae5921da08d64b',
#   'pengguna': 'ProjectKinu',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 4, 10)},
#  {'isi_tweet': '@lecriptovalute $CUM BSC #elon $musk contract: 0xc0d25180fd2e1549275ba13ea0ae5921da08d64b',
#   'pengguna': 'ProjectKinu',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 4)},
#  {'isi_tweet': '@Raja11114430 @ysiu @queersocialism @OptimoPrincipi $CUM BSC #elon $musk contract: 0xc0d25180fd2e1549275ba13ea0ae5921da08d64b',
#   'pengguna': 'ProjectKinu',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 3, 54)},
#  {'isi_tweet': '@IndianExpress $CUM BSC #elon $musk contract: 0xc0d25180fd2e1549275ba13ea0ae5921da08d64b',
#   'pengguna': 'ProjectKinu',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 3, 41)},
#  {'isi_tweet': '@erka_dal $CUM BSC #elon $musk contract: 0xc0d25180fd2e1549275ba13ea0ae5921da08d64b',
#   'pengguna': 'ProjectKinu',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 3, 15)},
#  {'isi_tweet': '@Steven13361225 $CUM BSC #elon $musk contract: 0xc0d25180fd2e1549275ba13ea0ae5921da08d64b',
#   'pengguna': 'ProjectKinu',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 3, 3)},
#  {'isi_tweet': '@Sahil_4596_ $CUM BSC #elon $musk contract: 0xc0d25180fd2e1549275ba13ea0ae5921da08d64b',
#   'pengguna': 'ProjectKinu',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 2, 50)},
#  {'isi_tweet': '@sendeyakino $CUM BSC #elon $musk contract: 0xc0d25180fd2e1549275ba13ea0ae5921da08d64b',
#   'pengguna': 'ProjectKinu',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 2, 29)},
#  {'isi_tweet': '@SafemoonFlushy $CUM BSC #elon $musk contract: 0xc0d25180fd2e1549275ba13ea0ae5921da08d64b',
#   'pengguna': 'ProjectKinu',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 2, 23)},
#  {'isi_tweet': '@whale_alert $CUM BSC #elon $musk contract: 0xc0d25180fd2e1549275ba13ea0ae5921da08d64b',
#   'pengguna': 'ProjectKinu',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 1, 45)},
#  {'isi_tweet': '@whale_alert $CUM BSC #elon $musk contract: 0xc0d25180fd2e1549275ba13ea0ae5921da08d64b',
#   'pengguna': 'ProjectKinu',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 1, 26)},
#  {'isi_tweet': '@Forbes $CUM BSC #elon $musk contract: 0xc0d25180fd2e1549275ba13ea0ae5921da08d64b',
#   'pengguna': 'ProjectKinu',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 1, 19)},
#  {'isi_tweet': 'Ada gak orang sanggup masukkan modal simpanan beli btc hanya sebab Elon Musk punya shitposting tweet.',
#   'pengguna': 'bisabilll',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 0, 42)},
#  {'isi_tweet': '@SIMPCERRI gak bakalan ngaruh mbak kalo Elon Musk turun gunung Elon Musk main dengan tim dan timnya orang orang ber… https://t.co/B9bPHt6Qmv',
#   'pengguna': 'Fahrid48307503',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 9, 58, 39)},
#  {'isi_tweet': 'RT @michaelbataraa: Gara-gara Elon Musk, tetangga gue yg tadinya main Crypto, sekarang main Kredivo wkwk.',
#   'pengguna': 'difaafnan_',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 9, 56, 27)},
#  {'isi_tweet': '@GlassBY1 gak bakalan ngaruh mbak kalo Elon Musk turun gunung Elon Musk main dengan tim dan timnya orang orang berd… https://t.co/FbTjyWWQ05',
#   'pengguna': 'Fahrid48307503',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 9, 55, 11)},
#  {'isi_tweet': '@Cryptofess_ elu lihat aja alamat address nya pasti itu itu lagi yg melakukan transaksi ketika Elon Musk sehabis ng… https://t.co/oFDzFTkIvJ',
#   'pengguna': 'Fahrid48307503',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 9, 52, 50)},
#  {'isi_tweet': 'Secercah Harapan Bitcoin Cs. Usai ‘Dihantam’ Elon Musk https://t.co/DKD2koyq43',
#   'pengguna': 'Bisniscom',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 9, 51, 5)},
#  {'isi_tweet': '@Cryptofess_ lol anda tidak memahami market crypto sekarang sudah masuk crypto war dimana pemerintah lewat influenc… https://t.co/hbaG7MN8an',
#   'pengguna': 'Fahrid48307503',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 9, 50, 14)},
#  {'isi_tweet': 'https://t.co/QI0VCE7Fwv.  UK\n\nhttps://t.co/4RtFB2O020   USA\n@elon@elonmusk @elon musk \n#reportelon',
#   'pengguna': 'garethvause',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 9, 47, 56)},
#  {'isi_tweet': 'RT @michaelbataraa: Gara-gara Elon Musk, tetangga gue yg tadinya main Crypto, sekarang main Kredivo wkwk.',
#   'pengguna': 'julyanmegano',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 9, 40, 59)},
#  {'isi_tweet': 'RT @3bearinthedark: Semua masuk surga kecuali elon musk',
#   'pengguna': 'abdawijaya',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 9, 40, 7)}]

# %%
tweet_negatif
# Out:
# [{'isi_tweet': 'Siapa yang tidak kenal Elon Musk? Sosok yang bisa bikin crypto gonjang-ganjing hanya dengan cuitan Twitternya ini t… https://t.co/oT1SmsIJ2M',
#   'pengguna': 'itdri_id',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 30, 58)},
#  {'isi_tweet': 'Capek2 belajar fundamental, Elon musk ngetweet dah langsung ambyar. Bukan aku tapi',
#   'pengguna': 'nndlnn',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 11, 35)},
#  {'isi_tweet': 'RT @Strategi_Bisnis: Ilmuwan2 top dlm bidang AI (artificial intelligence) yg kerja di Google, gajinya Rp 20 milyar/thn. 🤩\n\nPernah ada yg ma…',
#   'pengguna': 'Fadil31',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 11, 0, 10)},
#  {'isi_tweet': '@txtdrpemerintah Omongan belio kayaknya terdapat sandi tersembunyi. Perlu neuralink om Elon Musk Ini. https://t.co/iV9S5JRdf7',
#   'pengguna': 'uray_z',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 58, 22)},
#  {'isi_tweet': 'RT @coinvestasi: Masih anget, ini artikel yang jelasin kenapa Elon Musk gak cocok jadi panutan buat para investor crypto. Bukan financial a…',
#   'pengguna': 'izone__babydeul',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 57, 22)},
#  {'isi_tweet': 'RT @coinvestasi: Masih anget, ini artikel yang jelasin kenapa Elon Musk gak cocok jadi panutan buat para investor crypto. Bukan financial a…',
#   'pengguna': 'chresnas_putra',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 45, 20)},
#  {'isi_tweet': 'RT @NGIndonesia: Elon Musk menyatakan bahwa bahasa manusia mungkin akan berakhir setelah cip otak buatannya mulai digunakan. Dengan chip it…',
#   'pengguna': 'reza_zaka_',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 44, 25)},
#  {'isi_tweet': 'RT @Strategi_Bisnis: Ilmuwan2 top dlm bidang AI (artificial intelligence) yg kerja di Google, gajinya Rp 20 milyar/thn. 🤩\n\nPernah ada yg ma…',
#   'pengguna': 'ulil_albabb',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 33, 42)},
#  {'isi_tweet': 'RT @mojokdotco: Twit Elon Musk yang berisi tagar #Bitcoin dengan disertai emoticon patah hati ternyata langsung berpengaruh terhadap harga…',
#   'pengguna': 'notyourpriorty_',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 29, 9)},
#  {'isi_tweet': 'RT @coinvestasi: Masih anget, ini artikel yang jelasin kenapa Elon Musk gak cocok jadi panutan buat para investor crypto. Bukan financial a…',
#   'pengguna': 'AdiFh6',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 28, 15)},
#  {'isi_tweet': 'RT @NGIndonesia: Elon Musk menyatakan bahwa bahasa manusia mungkin akan berakhir setelah cip otak buatannya mulai digunakan. Dengan chip it…',
#   'pengguna': 'dianleica',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 25, 47)},
#  {'isi_tweet': 'RT @NGIndonesia: Elon Musk menyatakan bahwa bahasa manusia mungkin akan berakhir setelah cip otak buatannya mulai digunakan. Dengan chip it…',
#   'pengguna': 'L_Ghazi',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 24, 17)},
#  {'isi_tweet': 'Selain menteri² tak guna, aku tak suka elon musk juga.',
#   'pengguna': 'abdehhs',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 22, 36)},
#  {'isi_tweet': 'RT @Strategi_Bisnis: Ilmuwan2 top dlm bidang AI (artificial intelligence) yg kerja di Google, gajinya Rp 20 milyar/thn. 🤩\n\nPernah ada yg ma…',
#   'pengguna': 'bagasarrahman',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 21, 54)},
#  {'isi_tweet': 'RT @mojokdotco: Twit Elon Musk yang berisi tagar #Bitcoin dengan disertai emoticon patah hati ternyata langsung berpengaruh terhadap harga…',
#   'pengguna': 'nathlxrd',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 16, 45)},
#  {'isi_tweet': 'RT @coinvestasi: Masih anget, ini artikel yang jelasin kenapa Elon Musk gak cocok jadi panutan buat para investor crypto. Bukan financial a…',
#   'pengguna': 'kleepon',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 12, 50)},
#  {'isi_tweet': 'RT @Strategi_Bisnis: Ilmuwan2 top dlm bidang AI (artificial intelligence) yg kerja di Google, gajinya Rp 20 milyar/thn. 🤩\n\nPernah ada yg ma…',
#   'pengguna': 'andyptra_',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 9, 6)},
#  {'isi_tweet': 'RT @NGIndonesia: Elon Musk menyatakan bahwa bahasa manusia mungkin akan berakhir setelah cip otak buatannya mulai digunakan. Dengan chip it…',
#   'pengguna': 'ranuganda',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 6, 2)},
#  {'isi_tweet': 'RT @NGIndonesia: Elon Musk menyatakan bahwa bahasa manusia mungkin akan berakhir setelah cip otak buatannya mulai digunakan. Dengan chip it…',
#   'pengguna': 'cahyanugrahaa',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 5, 35)},
#  {'isi_tweet': 'Diajak orang ngomongin, elon musk, bitcoin, dan hitungan matematika lainnya, gue si ngerti tuh !',
#   'pengguna': 'profposer',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 10, 5, 20)},
#  {'isi_tweet': 'Elon musk kalo lagi gabut meresahkan sejagat maya ya mbah https://t.co/8biIkrk1du',
#   'pengguna': 'Gasskeun___',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 9, 58, 23)},
#  {'isi_tweet': 'Elon musk bersabda, kita miskin 🙂',
#   'pengguna': 'VickramSombu',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 9, 51, 11)},
#  {'isi_tweet': 'RT @NGIndonesia: Elon Musk menyatakan bahwa bahasa manusia mungkin akan berakhir setelah cip otak buatannya mulai digunakan. Dengan chip it…',
#   'pengguna': 'Mimiieea',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 9, 50, 15)},
#  {'isi_tweet': 'RT @mojokdotco: Twit Elon Musk yang berisi tagar #Bitcoin dengan disertai emoticon patah hati ternyata langsung berpengaruh terhadap harga…',
#   'pengguna': 'Syamsud76579252',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 9, 49, 33)},
#  {'isi_tweet': 'Twit Elon Musk yang berisi tagar #Bitcoin dengan disertai emoticon patah hati ternyata langsung berpengaruh terhada… https://t.co/OpLlN2JCxA',
#   'pengguna': 'mojokdotco',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 9, 47, 41)},
#  {'isi_tweet': 'RT @NGIndonesia: Elon Musk menyatakan bahwa bahasa manusia mungkin akan berakhir setelah cip otak buatannya mulai digunakan. Dengan chip it…',
#   'pengguna': 'DanielRezky3',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 9, 43, 58)},
#  {'isi_tweet': 'RT @NGIndonesia: Elon Musk menyatakan bahwa bahasa manusia mungkin akan berakhir setelah cip otak buatannya mulai digunakan. Dengan chip it…',
#   'pengguna': 'evettgo',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 6, 4, 9, 43, 1)}]
